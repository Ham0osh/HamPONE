# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp
from matplotlib import colors
from datetime import datetime
from IPython.display import clear_output
# %matplotlib nbagg
#%matplotlib inline

# %%
d = pd.read_csv("Hamish2.txt",delimiter='\t',header=None)
channel = np.array(d[0])
edge = np.array(d[1])
time = np.array(d[2])

# %% [markdown]
# # Data Overview

# %%
bns = 1*1000 # 1 second times 1000 ms to bin every ms
cn1=1
cn2=2
cn3=3
cn4=4
endTime=1e9 #1 second

pp.close()
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn1,edge==0),time<=endTime))],bins=bns,label="First", histtype="barstacked")
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn2,edge==0),time<=endTime))],bins=bns,label="Second", histtype="barstacked")
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn3,edge==0),time<=endTime))],bins=bns,label="Third", histtype="barstacked")
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn4,edge==0),time<=endTime))],bins=bns,label="Fourth", histtype="barstacked")
#pp.hist(time[channel==0],bins=bns,label="live time",histtype="step")
pp.yscale("log")
pp.legend(loc="upper left")
pp.xlabel("Time [s]")
pp.ylabel("Event Rate")
pp.title("Quiet Data rising edges over 1 second (1 bin per ms)")
pp.grid()
pp.show()

# %%
pp.close()
bns = 6000 # bin every 10 ms over 1 minute
cn1=1
cn2=2
cn3=3
cn4=4
endTime=60*1e9 #1 min

pp.close()
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn2,edge==0),time<=endTime))],bins=bns,label="Second", histtype="barstacked")
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn3,edge==0),time<=endTime))],bins=bns,label="Third", histtype="barstacked")
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn4,edge==0),time<=endTime))],bins=bns,label="Fourth", histtype="barstacked")
#pp.hist(time[channel==0],bins=bns,label="live time",histtype="step")
pp.yscale("log")
pp.legend(loc="upper left")
pp.xlabel("Time [s]")
pp.ylabel("Event Rate")
pp.title("Quiet Data rising edges over 1 minute (1 bin per 2 ms)")
pp.grid()
pp.show()

# %%
bns = 200 # bin every 5 ms
cn1=1
cn2=2
cn3=3
cn4=4
endTime=1e9 #1 second

pp.close()
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn1,edge==0),time<=endTime))],bins=bns,label="First", histtype="barstacked")
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn2,edge==0),time<=endTime))],bins=bns,label="Second", histtype="barstacked")
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn3,edge==0),time<=endTime))],bins=bns,label="Third", histtype="barstacked")
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn4,edge==0),time<=endTime))],bins=bns,label="Fourth", histtype="barstacked")
#pp.hist(time[channel==0],bins=bns,label="live time",histtype="step")
pp.yscale("log")
pp.legend(loc="upper left")
pp.xlabel("Time [s]")
pp.ylabel("Event Rate")
pp.title("Quiet Data rising edges over 1 second (200 bins)")
pp.grid()
pp.show()
# Out:
# <img src="data:image/png;base64,..." width="807">

# %%
pp.close()
bns = 200 # bin every 300 ms
cn1=1
cn2=2
cn3=3
cn4=4
endTime=60*1e9 #1 min
#60463699912.9

pp.close()
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn1,edge==0),time<=endTime))],bins=bns,label="Firsy", histtype="barstacked")
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn2,edge==0),time<=endTime))],bins=bns,label="Second", histtype="barstacked")
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn3,edge==0),time<=endTime))],bins=bns,label="Third", histtype="barstacked")
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn4,edge==0),time<=endTime))],bins=bns,label="Fourth", histtype="barstacked")
#pp.hist(time[channel==0],bins=bns,label="live time",histtype="step")
pp.yscale("log")
pp.legend(loc="upper left")
pp.xlabel("Time [s]")
pp.ylabel("Event Rate")
pp.title("Quiet Data rising edges over 1 minute (200 bins)")
pp.grid()
pp.show()
# Out:
# <img src="data:image/png;base64,..." width="815">

# %% [markdown]
# ## Start Cutting 'n' hits per bin for timesChannel

# %%
# Set all setting here ##################################################################################
pp.close()
startTime = 0*1e9
endTime = 60*1e9
nBins = 60000
ti = endTime - startTime
ms = 1e6 # ms
binRate = round((ti/ms)/nBins,0)
cutOff =  20                            # hits per bin to partition
timesChannel = 1                        # SET CHANNEL TO PULL BIN RANGES FROM
colour = {                              # automaticaly chooses colour
    1 : 'tab:blue',
    2 : 'Orange',
    3 : 'Green',
    4 : 'Red',
}
col = colour[timesChannel]              # overwrite colour here if you want

# Get counts of hits in each bin as well as a plot
counts, edges, plot = pp.hist(time[np.where(np.logical_and(np.logical_and(np.logical_and(channel==timesChannel,edge==0),time<=endTime),time>=startTime))],bins=nBins,label="channel " + str(timesChannel), histtype="barstacked", color = col)

pp.title("Hits in " + str(binRate) + " ms bins w/ " + str(cutOff) + " bin cutoff")
pp.xlabel("Time from 0 to 60 seconds")
pp.ylabel("Counts")
pp.legend(loc = 'upper right')
pp.axhline(cutOff, color = 'Gold') # SET LINE COLOUR HERE
pp.show()

lowOccuranceBins = []   # The following gets lists of bins with 1-cutOff hits and other, zero is used to count empty bins
otherBins = []
zeroBins = []
zero = 0
for _ in range(len(counts)):
    occ = counts[_]
    if (occ > 0 and occ <= cutOff):
        lowOccuranceBins.append([_*1e6 + startTime, occ])
    elif (occ == 0):
        zeroBins.append([_, occ])
        zero += 1
    else:
        otherBins.append([_, occ])

# Display results so tweaks can be made
print("# bins")
print(len(counts))
print("# bins with low occurances")
print(len(lowOccuranceBins))
print("# bins with more occurances")
print(len(otherBins))
print("# empty bins")
print(zero)
if( len(otherBins) == 0 ):
    highT = 0
    print("All Data below cutoff!")
# Out:
# <img src="data:image/png;base64,..." width="640">
# # bins
# 60000
# # bins with low occurances
# 59361
# # bins with more occurances
# 241
# # empty bins
# 398

# %%
pp.close()
print(lowOccuranceBins[0][0])    # show first bin
print(lowOccuranceBins[-1][0])   # show last bin
# Out:
# 0.0
# 59999000000.0

# %%
lowTimeRanges = []
lenL = len(lowOccuranceBins)
display(lenL) # Number of arrays before
_ = 0

while _ < lenL:                                       # iterate over each index _ in lowOccuraceBins
    t = lowOccuranceBins[_][0]                        # save the first value as t
    z = 1
    while (_ + z < lenL): # make sure in range
        if(lowOccuranceBins[_ + z][0] == t + z*1000000): # if the next entry is suxxessive in time
            z += 1                                             # go to the next entry
        else:                                            
            break                                              # break if not successive
    lowTimeRanges.append([t, lowOccuranceBins[_ + z - 1][0] + 1000000])  # save start and end time values
    _ = _ + z                                                  # move the index to the next entry that is not succesive
    
display('VVVVV')
display(len(lowTimeRanges)) # Number of arrays after
#print(lowTimeRanges)
# Out:
# 59361
# 'VVVVV'
# 580

# %%
def lowTimeBool(time, lowTimeRanges): #Returns true or false if that time is in the range
    for rang in lowTimeRanges:
        if( np.logical_and(time>=rang[0],time<rang[1])):
            #display(time)
            return True
    #display(time)
    return False

# %%
def lowTimeFile(time, lowTimeRanges, tmax = 60000000000.0,tmin = 0): #Sorts times in/out of rangeand returns 2 arrays
    # tmax and tmin are used for the % completion
    # for each time value in time, look and see if it falls within one of the lowTimeRanges
    # then save it to the corresponding array
    start = datetime.now()
    lowTimeArray = []
    otherTimeArray = []
    for _ in range(len(time)):
        val = False
        clear_output(wait=True)
        display(str(round((time[_]-tmin)*100 / (tmax-tmin), 3)) + " %")
        for rang in lowTimeRanges:
            if( np.logical_and( time[_] >= rang[0], time[_] < rang[1] ) ):
                val = True
        if(val):
            lowTimeArray.append(time[_])
        else:
            otherTimeArray.append(time[_])
    #lowTimeArray = np.array(lowTimeArray)     #uncomment if you need an np.array (better for memory maybe?)
    #otherTimeArray = np.array(otherTimeArray)
    end = datetime.now()
    print("DONE (∩｀-´)⊃━☆ﾟ.*･｡ﾟ " + str(end-start))
    return lowTimeArray, otherTimeArray

# %% [markdown]
# ## Get time values from one thresh using ranges of another

# %% [markdown]
# # Use hits from threhsold 1

# %%
# This runs the above on set_channel
HitsChannel = 1
lowTimes, highTimes = lowTimeFile(time[np.logical_and(np.logical_and(np.logical_and(channel==HitsChannel,edge==0), time<=endTime),time>=startTime)], lowTimeRanges, endTime, startTime)
# change set_channel to 1-4 if you want to use one thresholds time ranges on another threshold
# only the firs ttwo arguments are necessary
print()
print(len(lowTimes))
print()
print(len(highTimes))
# Out:
# '14.2 %'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-7a9bb549e85e> in <module>
#       1 # This runs the above on set_channel
#       2 HitsChannel = 1
# ----> 3 lowTimes, highTimes = lowTimeFile(time[np.logical_and(np.logical_and(np.logical_and(channel==HitsChannel,edge==0), time<=endTime),time>=startTime)], lowTimeRanges, endTime, startTime)
#       4 # change set_channel to 1-4 if you want to use one thresholds time ranges on another threshold
#       5 # only the firs ttwo arguments are necessary
#
# <ipython-input-7-a79e5de06e2b> in lowTimeFile(time, lowTimeRanges, tmax, tmin)
#       8     for _ in range(len(time)):
#       9         val = False
# ---> 10         clear_output(wait=True)
#      11         display(str(round((time[_]-tmin)*100 / (tmax-tmin), 3)) + " %")
#      12         for rang in lowTimeRanges:
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\IPython\core\display.py in clear_output(wait)
#    1462     from IPython.core.interactiveshell import InteractiveShell
#    1463     if InteractiveShell.initialized():
# -> 1464         InteractiveShell.instance().display_pub.clear_output(wait)
#    1465     else:
#    1466         print('\033[2K\r', end='')
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\ipykernel\zmqshell.py in clear_output(self, wait)
#     155         """
#     156         content = dict(wait=wait)
# --> 157         self._flush_streams()
#     158         self.session.send(
#     159             self.pub_socket, u'clear_output', content,
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\ipykernel\zmqshell.py in _flush_streams(self)
#      78         """flush IO Streams prior to display"""
#      79         sys.stdout.flush()
# ---> 80         sys.stderr.flush()
#      81
#      82     @default('_thread_local')
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\ipykernel\iostream.py in flush(self)
#     350                 self.pub_thread.schedule(evt.set)
#     351                 # and give a timeout to avoid
# --> 352                 if not evt.wait(self.flush_timeout):
#     353                     # write directly to __stderr__ instead of warning because
#     354                     # if this is happening sys.stderr may be the problem.
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\threading.py in wait(self, timeout)
#     304             else:
#     305                 if timeout > 0:
# --> 306                     gotit = waiter.acquire(True, timeout)
#     307                 else:
#     308                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
bns = 200
one_s_bins, *trash = np.histogram(lowTimes,bins=60)
#two_s_bins, *trash = np.histogram(highTimes,bins=60)

pp.close()
pp.hist(highTimes, bins = bns, label = "High Times", histtype = "step")
pp.hist(lowTimes, bins = bns, label = "Low Times", histtype = "step")
pp.legend()
pp.xlabel('x')
pp.ylabel("Count")
pp.title("Low & High times over time (" + str(bns)+" bins)\nHits from cn " + str(HitsChannel) + " & Time ranges from cn" + str(timesChannel))
pp.show()

# Shows histogram of recorded hits in low/high times over the entire time
# Out:
# <img src="data:image/png;base64,..." width="793">

# %%
pp.close()
# Why are we taking a histogram of a histogram here, is it necessary (not for code)
pp.hist(one_s_bins, bins = bns, label = "Low Times", histtype = "step", color = 'Orange')
pp.legend()
pp.xlabel('x')
pp.ylabel("Count")
pp.title("Histogram of the histogram (" + str(bns)+" bins) - Hits from cn " + str(HitsChannel) + " & Time ranges from cn" + str(timesChannel))
pp.show()
# This histogram was useful when we set the threshold between high/low time manualy
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def getDiffs(tymes):
    # For each time given, find how long until the next time
    # Return it as an array of time differences
    diffs = []
    for _ in range(len(tymes) - 1):
        diffs.append(tymes[_+1] - tymes[_])
    return diffs

lowDiffs = getDiffs(lowTimes)
highDiffs = getDiffs(highTimes)
allDiffs = lowDiffs + highDiffs

display(len(lowDiffs))
display()
display(len(highTimes))
# Out:
# 357127
# 5729

# %%
pp.close()
bns = 240
timeLength = int((endTime - startTime)*1e-9)
ax = pp.subplot(1,1,1)
ax.hist(np.log10(highDiffs), bins = bns, histtype = 'step', density = True, label = 'High rate')
ax.hist(np.log10(lowDiffs), bins = bns, histtype = 'step', density = True, label = 'Low rate')
ax.hist(np.log10(allDiffs), bins = bns, histtype = 'step', density = True, label = 'All')
ax.grid()
ax.set_axisbelow(True)
ax.set_xlim(1.2,9)            # Set range of X and Y
#ax.set_ylim(-0.05,0.8)
lab = " #" + str(timesChannel)
ax.plot([], [], ' ', label="$\\bf{Time Range :}$" + lab)
lab2 = " #" + str(HitsChannel)
ax.plot([], [], ' ', label="$\\bf{Hits From :}$" + lab2)
ax.legend(loc = 'upper left')
ax.set_ylabel("Normalized Counts")
ax.set_xlabel(r"$\mathrm{log}_{10} \left(\Delta t/\mathrm{ns}\right)$")
ax.set_title("Normalized Time Difference between Consecutive Hits\n " + str(timeLength) + " sec and binning per " + str(binRate) + " ms and " + str(cutOff) + " hit cutoff")
pp.show()
# Out:
# <img src="data:image/png;base64,..." width="751">
# <ipython-input-12-d8a6b3a6cd31>:6: RuntimeWarning: invalid value encountered in log10
#   ax.hist(np.log10(lowDiffs), bins = bns, histtype = 'step', density = True, label = 'Low rate')
# C:\Users\hamis\AppData\Local\Programs\Python\Python38-32\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\hamis\AppData\Local\Programs\Python\Python38-32\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# <ipython-input-12-d8a6b3a6cd31>:7: RuntimeWarning: invalid value encountered in log10
#   ax.hist(np.log10(allDiffs), bins = bns, histtype = 'step', density = True, label = 'All')
# C:\Users\hamis\AppData\Local\Programs\Python\Python38-32\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\hamis\AppData\Local\Programs\Python\Python38-32\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# # Use hits from threhsold 2

# %%
# This runs the above on set_channel
HitsChannel = 2
lowTimes, highTimes = lowTimeFile(time[np.logical_and(np.logical_and(np.logical_and(channel==HitsChannel,edge==0), time<=endTime),time>=startTime)], lowTimeRanges, endTime, startTime)
# only the first two arguments are necessary
print()
print(len(lowTimes))
print()
print(len(highTimes))
# Out:
# '99.998 %'
# DONE (∩｀-´)⊃━☆ﾟ.*･｡ﾟ 0:04:22.692409
#
# 99560
#
# 1689

# %%
bns = 200
one_s_bins, *trash = np.histogram(lowTimes,bins=60)
#two_s_bins, *trash = np.histogram(highTimes,bins=60)

pp.close()
pp.hist(highTimes, bins = bns, label = "High Times", histtype = "step")
pp.hist(lowTimes, bins = bns, label = "Low Times", histtype = "step")
pp.legend()
pp.xlabel('x')
pp.ylabel("Count")
pp.title("Low & High times over time (" + str(bns)+" bins)\nHits from cn " + str(HitsChannel) + " & Time ranges from cn" + str(timesChannel))
pp.show()

# Shows histogram of recorded hits in low/high times over the entire time
# Out:
# <img src="data:image/png;base64,..." width="791">

# %%
pp.close()
# Why are we taking a histogram of a histogram here, is it necessary (not for code)
pp.hist(one_s_bins, bins = bns, label = "Low Times", histtype = "step", color = 'Orange')
pp.legend()
pp.xlabel('x')
pp.ylabel("Count")
pp.title("Histogram of the histogram (" + str(bns)+" bins) - Hits from cn " + str(HitsChannel) + " & Time ranges from cn" + str(timesChannel))
pp.show()
# This histogram was useful when we set the threshold between high/low time manualy
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def getDiffs(tymes):
    # For each time given, find how long until the next time
    # Return it as an array of time differences
    diffs = []
    for _ in range(len(tymes) - 1):
        diffs.append(tymes[_+1] - tymes[_])
    return diffs

lowDiffs = getDiffs(lowTimes)
highDiffs = getDiffs(highTimes)
allDiffs = lowDiffs + highDiffs

display(len(lowDiffs))
display()
display(len(highTimes))
# Out:
# 99559
# 1689

# %%
pp.close()
bns = 240
timeLength = int((endTime - startTime)*1e-9)
ax = pp.subplot(1,1,1)
ax.hist(np.log10(highDiffs), bins = bns, histtype = 'step', density = True, label = 'High rate')
ax.hist(np.log10(lowDiffs), bins = bns, histtype = 'step', density = True, label = 'Low rate')
ax.hist(np.log10(allDiffs), bins = bns, histtype = 'step', density = True, label = 'All')
ax.grid()
ax.set_axisbelow(True)
ax.set_xlim(1.2,9)            # Set range of X and Y
#ax.set_ylim(-0.05,0.8)
lab = " #" + str(timesChannel)
ax.plot([], [], ' ', label="$\\bf{Time Range :}$" + lab)
lab2 = " #" + str(HitsChannel)
ax.plot([], [], ' ', label="$\\bf{Hits From :}$" + lab2)
ax.legend(loc = 'upper left')
ax.set_ylabel("Normalized Counts")
ax.set_xlabel(r"$\mathrm{log}_{10} \left(\Delta t/\mathrm{ns}\right)$")
ax.set_title("Normalized Time Difference between Consecutive Hits\n " + str(timeLength) + " sec and binning per " + str(binRate) + " ms and " + str(cutOff) + " hit cutoff")
pp.show()
# Out:
# <img src="data:image/png;base64,..." width="751">

# %%
pp.close()

# %% [markdown]
# # Use hits from threhsold 3

# %%
# This runs the above on set_channel
HitsChannel = 3
lowTimes, highTimes = lowTimeFile(time[np.logical_and(np.logical_and(np.logical_and(channel==HitsChannel,edge==0), time<=endTime),time>=startTime)], lowTimeRanges, endTime, startTime)
# change set_channel to 1-4 if you want to use one thresholds time ranges on another threshold
# only the firs ttwo arguments are necessary
print()
print(len(lowTimes))
print()
print(len(highTimes))
# Out:
# '99.951 %'
# DONE (∩｀-´)⊃━☆ﾟ.*･｡ﾟ 0:00:08.911473
#
# 3469
#
# 87

# %%
bns = 200
one_s_bins, *trash = np.histogram(lowTimes,bins=60)
#two_s_bins, *trash = np.histogram(highTimes,bins=60)

pp.close()
pp.hist(highTimes, bins = bns, label = "High Times", histtype = "step")
pp.hist(lowTimes, bins = bns, label = "Low Times", histtype = "step")
pp.legend()
pp.xlabel('x')
pp.ylabel("Count")
pp.title("Low & High times over time (" + str(bns)+" bins)\nHits from cn " + str(HitsChannel) + " & Time ranges from cn" + str(timesChannel))
pp.show()

# Shows histogram of recorded hits in low/high times over the entire time
# Out:
# <img src="data:image/png;base64,..." width="778">

# %%
pp.close()
# Why are we taking a histogram of a histogram here, is it necessary (not for code)
pp.hist(one_s_bins, bins = bns, label = "Low Times", histtype = "step", color = 'Green')
pp.legend()
pp.xlabel('x')
pp.ylabel("Count")
pp.title("Histogram of the histogram (" + str(bns)+" bins) - Hits from cn " + str(HitsChannel) + " & Time ranges from cn" + str(timesChannel))
pp.show()
# This histogram was useful when we set the threshold between high/low time manualy
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def getDiffs(tymes):
    # For each time given, find how long until the next time
    # Return it as an array of time differences
    diffs = []
    for _ in range(len(tymes) - 1):
        diffs.append(tymes[_+1] - tymes[_])
    return diffs

lowDiffs = getDiffs(lowTimes)
highDiffs = getDiffs(highTimes)
allDiffs = lowDiffs + highDiffs

display(len(lowDiffs))
display()
display(len(highTimes))
# Out:
# 3468
# 87

# %%
pp.close()
bns = 240
timeLength = int((endTime - startTime)*1e-9)
ax = pp.subplot(1,1,1)
ax.hist(np.log10(highDiffs), bins = bns, histtype = 'step', density = True, label = 'High rate')
ax.hist(np.log10(lowDiffs), bins = bns, histtype = 'step', density = True, label = 'Low rate')
ax.hist(np.log10(allDiffs), bins = bns, histtype = 'step', density = True, label = 'All')
ax.grid()
ax.set_axisbelow(True)
ax.set_xlim(1.2,9)            # Set range of X and Y
#ax.set_ylim(-0.05,0.8)
lab = " #" + str(timesChannel)
ax.plot([], [], ' ', label="$\\bf{Time Range :}$" + lab)
lab2 = " #" + str(HitsChannel)
ax.plot([], [], ' ', label="$\\bf{Hits From :}$" + lab2)
ax.legend(loc = 'upper left')
ax.set_ylabel("Normalized Counts")
ax.set_xlabel(r"$\mathrm{log}_{10} \left(\Delta t/\mathrm{ns}\right)$")
ax.set_title("Normalized Time Difference between Consecutive Hits\n " + str(timeLength) + " sec and binning per " + str(binRate) + " ms and " + str(cutOff) + " hit cutoff")
pp.show()
# Out:
# <img src="data:image/png;base64,..." width="746">

# %%
pp.close()

# %% [markdown]
# # Use hits from threhsold 4

# %%
# This runs the above on set_channel
HitsChannel = 4
lowTimes, highTimes = lowTimeFile(time[np.logical_and(np.logical_and(np.logical_and(channel==HitsChannel,edge==0), time<=endTime),time>=startTime)], lowTimeRanges, endTime, startTime)
# change set_channel to 1-4 if you want to use one thresholds time ranges on another threshold
# only the firs ttwo arguments are necessary
print()
print(len(lowTimes))
print()
print(len(highTimes))
# Out:
# '99.758 %'
# DONE (∩｀-´)⊃━☆ﾟ.*･｡ﾟ 0:00:02.554889
#
# 957
#
# 17

# %%
bns = 200
one_s_bins, *trash = np.histogram(lowTimes,bins=60)
#two_s_bins, *trash = np.histogram(highTimes,bins=60)

pp.close()
pp.hist(highTimes, bins = bns, label = "High Times", histtype = "step")
pp.hist(lowTimes, bins = bns, label = "Low Times", histtype = "step")
pp.legend()
pp.xlabel('x')
pp.ylabel("Count")
pp.title("Low & High times over time (" + str(bns)+" bins)\nHits from cn " + str(HitsChannel) + " & Time ranges from cn" + str(timesChannel))
pp.show()

# Shows histogram of recorded hits in low/high times over the entire time
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pp.close()
# Why are we taking a histogram of a histogram here, is it necessary (not for code)
pp.hist(one_s_bins, bins = bns, label = "Low Times", histtype = "step", color = 'Red')
pp.legend()
pp.xlabel('x')
pp.ylabel("Count")
pp.title("Histogram of the histogram (" + str(bns)+" bins) - Hits from cn " + str(HitsChannel) + " & Time ranges from cn" + str(timesChannel))
pp.show()
# This histogram was useful when we set the threshold between high/low time manualy
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def getDiffs(tymes):
    # For each time given, find how long until the next time
    # Return it as an array of time differences
    diffs = []
    for _ in range(len(tymes) - 1):
        diffs.append(tymes[_+1] - tymes[_])
    return diffs

lowDiffs = getDiffs(lowTimes)
highDiffs = getDiffs(highTimes)
allDiffs = lowDiffs + highDiffs

display(len(lowDiffs))
display()
display(len(highTimes))
# Out:
# 956
# 17

# %%
pp.close()
bns = 240
timeLength = int((endTime - startTime)*1e-9)
ax = pp.subplot(1,1,1)
ax.hist(np.log10(highDiffs), bins = bns, histtype = 'step', density = True, label = 'High rate')
ax.hist(np.log10(lowDiffs), bins = bns, histtype = 'step', density = True, label = 'Low rate')
ax.hist(np.log10(allDiffs), bins = bns, histtype = 'step', density = True, label = 'All')
ax.grid()
ax.set_axisbelow(True)
ax.set_xlim(1.2,9)            # Set range of X and Y
ax.set_ylim(0,2)
lab = " #" + str(timesChannel)
ax.plot([], [], ' ', label="$\\bf{Time Range :}$" + lab)
lab2 = " #" + str(HitsChannel)
ax.plot([], [], ' ', label="$\\bf{Hits From :}$" + lab2)
ax.legend(loc = 'upper left')
ax.set_ylabel("Normalized Counts")
ax.set_xlabel(r"$\mathrm{log}_{10} \left(\Delta t/\mathrm{ns}\right)$")
ax.set_title("Normalized Time Difference between Consecutive Hits\n " + str(timeLength) + " sec and binning per " + str(binRate) + " ms and " + str(cutOff) + " hit cutoff")
pp.show()
# Out:
# <img src="data:image/png;base64,..." width="770">

# %%
pp.close()
