# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp
#%matplotlib nbagg

# %%
d = pd.read_csv("unpacked.txt", delimiter="\t", header=None)
channel = np.array(d[0])
edge    = np.array(d[1])
time    = np.array(d[2])

# %%
d
# Out:
#           0  1             2
# 0         0  0  1.000000e+05
# 1         1  0  5.800500e+03
# 2         1  1  5.835400e+03
# 3         1  0  8.933000e+03
# 4         1  1  8.967800e+03
# ...      .. ..           ...
# 12740338  6  1  5.871848e+10
# 12740339  6  0  5.871849e+10
# 12740340  6  1  5.871849e+10
# 12740341  9  1  5.871840e+10
# 12740342  9  0  5.871850e+10
#
# [12740343 rows x 3 columns]

# %%
pp.plot(time[channel==0])
pp.show()
# Out:
# <img src="data:image/png;base64,..." width="258">

# %% [markdown]
# ### Lowest Threshold

# %%
pp.close()
pp.hist(time[channel==1],bins=200,label="Up", histtype="step")
pp.hist(time[channel==5],bins=200,label="Down", histtype="step")
pp.hist(time[channel==0],bins=200,label="live time",histtype="step")
pp.yscale("log")
pp.legend()
pp.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Second Lowest Threshold

# %%
pp.close()
pp.hist(time[channel==2],bins=200,label="Up", histtype="step")
pp.hist(time[channel==6],bins=200,label="Down", histtype="step")
pp.hist(time[channel==0],bins=200,label="live time",histtype="step")
pp.yscale("log")
pp.legend()
pp.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Second Highest Threshold

# %%
pp.close()
pp.hist(time[channel==3],bins=200,label="Up", histtype="step")
pp.hist(time[channel==7],bins=200,label="Down", histtype="step")
pp.hist(time[channel==0],bins=200,label="live time",histtype="step")
pp.yscale("log")
pp.legend()
pp.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Highest Threshold

# %%
pp.close()
pp.hist(time[channel==4],bins=200,label="Up", histtype="step")
pp.hist(time[channel==8],bins=200,label="Down", histtype="step")
pp.hist(time[channel==0],bins=200,label="live time",histtype="step")
pp.yscale("log")
pp.legend()
pp.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Lets look at Edges

# %%
pp.close()
bns = 200
cn1=1
cn2=5
uphist =   np.histogram(time[np.where(np.logical_and(channel==cn1,edge==0))],bins=bns)
downhist = np.histogram(time[np.where(np.logical_and(channel==cn2,edge==1))],bins=bns)
pp.figure()
pp.plot(uphist[1][:-1]/1e9,uphist[0],'x-',label='up',color="C0")
pp.plot(downhist[1][:-1]/1e9,downhist[0],'x-',label='down',color="C1")
pp.yscale("log")
pp.legend(loc="upper left")
pp.xlabel("Time [s]")
pp.ylabel("Event Rate")
pp.title("Rising Edges for sDOM1 Hamish Copy")
pp.grid()
pp.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
bns = 200
cn1=1
cn2=2
cn3=3
cn4=4
endTime=1e9 #1 second

pp.close()
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn1,edge==0),time<=endTime))],bins=bns,label="min", histtype="barstacked")
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn2,edge==0),time<=endTime))],bins=bns,label="second low", histtype="barstacked")
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn3,edge==0),time<=endTime))],bins=bns,label="secon high", histtype="barstacked")
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn4,edge==0),time<=endTime))],bins=bns,label="max", histtype="barstacked")
#pp.hist(time[channel==0],bins=bns,label="live time",histtype="step")
pp.yscale("log")
pp.legend(loc="upper left")
pp.xlabel("Time [s]")
pp.ylabel("Event Rate")
pp.title("sDOM1 Rising Edge Top over 1 second - Hamish")
pp.grid()
pp.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
bns = 200
cn1=1
cn2=2
cn3=3
cn4=4
endTime=60*1e9 #1 min

pp.close()
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn1,edge==0),time<=endTime))],bins=bns,label="min", histtype="barstacked")
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn2,edge==0),time<=endTime))],bins=bns,label="second low", histtype="barstacked")
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn3,edge==0),time<=endTime))],bins=bns,label="secon high", histtype="barstacked")
pp.hist(time[np.where(np.logical_and(np.logical_and(channel==cn4,edge==0),time<=endTime))],bins=bns,label="max", histtype="barstacked")
pp.hist(time[channel==0],bins=bns,label="live time",histtype="step")
pp.yscale("log")
pp.legend(loc="upper left")
pp.xlabel("Time [s]")
pp.ylabel("Event Rate")
pp.title("sDOM1 Rising Edges over 1 minute - Hamish")
pp.grid()
pp.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
